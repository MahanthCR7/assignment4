# %% [markdown]
# TASK 1
#
# Problem Statement:
# Discuss the concept of hooks in React. Explain how they differ from class component lifecycle methods. Also, provide an example
#
# Answer:
# Hooks in React are functions that allow us to use state and lifecycle features in functional components.
#
# Difference:
#
# Class components use lifecycle methods like componentDidMount
#
# Hooks use functions like useEffect
#
# Hooks make code simpler and reusable

# %%
import React, { useState } from "react";

function Counter() {
  const [count, setCount] = useState(0);

  return (
    <div>
      <p>{count}</p>
      <button onClick={() => setCount(count + 1)}>Click</button>
    </div>
  );
}

# %% [markdown]
# TASK 2
#
# Problem Statement:
# Explain and discuss its syntax, purpose, and how it manages state in functional components for the following hooks: useState, useEffect

# %%
useState

Used to manage state in functional components

Syntax:

const [state, setState] = useState(initialValue);

Example:

const [count, setCount] = useState(0);

useEffect

Used to handle side effects like API calls or DOM updates

Syntax:

useEffect(() => {
  // code
}, []);

Example:

useEffect(() => {
  console.log("Component Mounted");
}, []);

# %% [markdown]
# TASK 3
#
# Problem Statement:
# Explain the concept of custom hooks in React. Provide one example scenario and code
#
# Answer:
# Custom hooks are user-defined hooks used to reuse logic across components.
#
# Use case: Fetching data from an API
#
# Example:

# %%
import { useState, useEffect } from "react";

function useFetch(url) {
  const [data, setData] = useState(null);

  useEffect(() => {
    fetch(url)
      .then(res => res.json())
      .then(data => setData(data));
  }, [url]);

  return data;
}

# %% [markdown]
# TASK 4
#
# Problem Statement:
# Explore ways to optimize performance in React using hooks
#
# Answer:
#
# Use useMemo to memoize values
#
# Use useCallback to prevent function recreation
#
# Use React.memo to avoid unnecessary re-renders
#
# Avoid unnecessary state updates
#
# Use correct dependency arrays in useEffect

# %% [markdown]
# TASK 5
#
# Problem Statement:
# Implement a global state management system using Context API and useContext hook

# %%
import React, { createContext, useContext, useState } from "react";

const ThemeContext = createContext();

function App() {
  const [theme, setTheme] = useState("light");

  return (
    <ThemeContext.Provider value={theme}>
      <Child />
    </ThemeContext.Provider>
  );
}

function Child() {
  const theme = useContext(ThemeContext);

  return <h1>Theme: {theme}</h1>;
}

export default App;
